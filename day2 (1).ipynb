# %% [markdown]
# <h1>DAY 2 -AICW</h1>

# %% [markdown]
# #### Python basic

# %%
print("welcome aicw")
# Out:
# welcome aicw

# %%
name='indu'
print(name)
# Out:
# indu

# %%
name
# Out:
# 'indu'

# %%
type(name)
# Out:
# str

# %%
age=20
print(age)
# Out:
# 20

# %%
#para

# %%
para='''
this is line 1
2
3
p
# Out:
#   Cell In[16], line 5
#     print(''')
#              ^
# SyntaxError: unmatched ')'

# %%
lst = ['indu',20,'gsss']

# %%
type(lst)
# Out:
# list

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
#if we dont knoe the spelling use shift+tab
#inside the bracket if we dont know what to write shift+tab

# %%
lst.append("shree")
lst
# Out:
# ['indu', 20, 'gsss', 'shree']

# %%
lst1 = lst.copy()
lst1
# Out:
# ['indu', 20, 'gsss', 'shree']

# %%
lst.count(20)
# Out:
# 1

# %%
#iterable = list,tuples

# %%
lst2=['mango','apple']
lst2.extend(lst1)
lst2
# Out:
# ['mango', 'apple', 'indu', 20, 200, 200, 200, 'gsss', 'shree']

# %%
lst1.index(20)
# Out:
# 1

# %%
lst1.insert(2,200)
lst1
# Out:
# ['indu', 20, 200, 200, 200, 'gsss', 'shree']

# %%
lst1.pop(-2)
# Out:
# 'gsss'

# %%
lst1.remove(20)

# %%
#remove will not give output until u call list

# %%
lst1
# Out:
# ['indu', 200, 200, 200, 'shree']

# %%
lst1.reverse()

# %%
lst1
# Out:
# ['shree', 200, 200, 200, 'indu']

# %%
#for string

# %%
x ='smr'
x[::-1]
# Out:
# 'rms'

# %%
lst1.clear()
lst1
# Out:
# []

# %%
#tuple -()-immutable-diff datatypes

# %%
tup = ("edunet",2015)
tup
# Out:
# ('edunet', 2015)

# %%
type(tup)
# Out:
# tuple

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
tup.count(2015)
# Out:
# 1

# %%
tup.index(2015)
# Out:
# 1

# %%
#set-{} - unique element(no duplecate)

# %%
s1={'name','age'}

# %%
type(s1)
# Out:
# set

# %%
s1
# Out:
# {'age', 'name'}

# %%
s2={23,56,70,56}
s2
# Out:
# {23, 56, 70}

# %%
dir(set)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
print (s1)
print (s2)
# Out:
# {'name', 'age'}
# {56, 70, 23}

# %%
s1.union(s2)
# Out:
# {23, 56, 70, 'age', 'name'}

# %%
s1.intersection(s2)
# Out:
# set()

# %%
s3 = {90,56,2004,2015}
s2.intersection(s3)
# Out:
# {56}

# %%
s3={90,56,2004,2015}
s1.intersection(s3)
# Out:
# set()

# %%
s1.isdisjoint(s2)
# Out:
# True

# %%
s2.discard(s1)

# %%
s1
# Out:
# {'age', 'name'}

# %%
s2
# Out:
# {23, 56, 70}

# %%
#dictionary -{} - keys unique

# %%
dc = {'name':'indu',
     'place':'mysuru',
     'age':20}
dc
# Out:
# {'name': 'indu', 'place': 'mysuru', 'age': 20}

# %%
dir(dc)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
dc.keys()
# Out:
# dict_keys(['name', 'place', 'age'])

# %%
dc.values()
# Out:
# dict_values(['indu', 'mysuru', 20])

# %%
#loops

# %%
for i in range(0,12,2): #2 is step size #for even number
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
for i in range(1,12,2): #2 is step size #for odd number
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
# 11

# %%
def add(x,y):
    return x+y

# %%
add(3,5)
# Out:
# 8

# %% [markdown]
# add(3,5,6) -> it gives argument error

# %%
def add1(*args):
    return sum(args)
add1(20,50,10,5,9)
# Out:
# 94

# %%
x=1
while True:
    if x%5==0:
     break
    print(x)
    x+=1
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# OOPS

# %%
class student:
    pass
i = student()

# %%
i

# %%
class student:
    def __init__(self,name,place): # it is  called as dander method(#init is constracter)
        self.name=name
        self.place=place

    def show(self): # instance method
        return f'the name is {self.name} and you are from {self.place}'
p1=student('indu','mysore')
p1.show()
# Out:
# 'the name is indu and you are from mysore'

# %%
p1.name
# Out:
# 'indu'

# %%
p1.place
# Out:
# 'mysore'

# %%
p1.age
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 p1.age
#
# AttributeError: 'student' object has no attribute 'age'

# %% [markdown]
# to update another thing

# %%
class student:
    def __init__(std,usn,name,place): # it is  called as dander method(#init is constracter)
        std.usn=usn
        std.name=name
        std.place=place

    def show(std): # instance method
        return (f'usn {std.usn} the name is {std.name} and you are from {std.place}')
    def update(std):
        std.age=age
        std.clg=clg
p1=student('768708','indu','mysore')
p1.show()
# Out:
# 'usn 768708 the name is indu and you are from mysore'

# %%
p1.show()
# Out:
# 'usn 768708 the name is indu and you are from mysore'

# %%
p1.update(20,'GSSS')

# %%
p1.show()
# Out:
# 'usn 768708 the name is indu and you are from mysore'
